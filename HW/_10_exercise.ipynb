# %% [markdown]
# ![image.png](attachment:25ff5171-c2ed-43e2-a934-268a15a1e746.png)

# %%
import numpy as np
import scipy as sp
import cvxpy as cp
import matplotlib.pyplot as plt
import jax, jax.numpy as jnp

# %%
n = 


c = 
A = 
b =

# %%
f = lambda x: c.T @ x + jnp.sum(jnp.log(x))
